# %%
import pandas as pd

# %%
path = "https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv"

df = pd.read_csv(path)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##### Validate dataframe

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### Trabalhando com o index

# %%
df.set_index("PassengerId")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df = df.set_index("PassengerId")

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.set_index(["Sex", "Age"])
# Out:
#              Survived  Pclass  \
# Sex    Age
# male   22.0         0       3
# female 38.0         1       1
#        26.0         1       3
#        35.0         1       1
# male   35.0         0       3
# ...               ...     ...
#        27.0         0       2
# female 19.0         1       1
#        NaN          0       3
# male   26.0         1       1
#        32.0         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# male   35.0                           Allen, Mr. William Henry      0      0
# ...                                                        ...    ...    ...
# ...

# %%
df_ind2 = df.set_index(["Sex", "Age"])

# %%
df_ind2
# Out:
#              Survived  Pclass  \
# Sex    Age
# male   22.0         0       3
# female 38.0         1       1
#        26.0         1       3
#        35.0         1       1
# male   35.0         0       3
# ...               ...     ...
#        27.0         0       2
# female 19.0         1       1
#        NaN          0       3
# male   26.0         1       1
#        32.0         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# male   35.0                           Allen, Mr. William Henry      0      0
# ...                                                        ...    ...    ...
# ...

# %%
df_ind2.loc[["female", "male"]]
# Out:
#              Survived  Pclass  \
# Sex    Age
# female 38.0         1       1
#        26.0         1       3
#        35.0         1       1
#        27.0         1       3
#        14.0         1       2
# ...               ...     ...
# male   28.0         0       2
#        25.0         0       3
#        27.0         0       2
#        26.0         1       1
#        32.0         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
#        27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      0      2
#        14.0                Nasser, Mrs. Nicholas (Adele Achem)      1      0
# ...                                                        ...    ...    ...
# ...

# %%
df_ind2.loc[[("female", 38)]]
# Out:
#              Survived  Pclass  \
# Sex    Age
# female 38.0         1       1
#        38.0         1       3
#        38.0         1       1
#        38.0         0       2
#        38.0         1       1
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        38.0  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      1      5
#        38.0                                Icard, Miss. Amelie      0      0
#        38.0                          Funk, Miss. Annie Clemmer      0      0
#        38.0                      Endres, Miss. Caroline Louise      0      0
#
#                Ticket      Fare Cabin Embarked
# Sex    Age
# female 38.0  PC 17599   71.2833   C85        C
#        38.0    347077   31.3875   NaN        S
#        38.0    113572   80.0000   B28      NaN
#        38.0    237671   13.0000   NaN        S
# ...

# %%
df_ind2.sort_index(ascending=[True, False])
# Out:
#              Survived  Pclass  \
# Sex    Age
# female 63.0         1       1
#        63.0         1       3
#        62.0         1       1
#        60.0         1       1
#        58.0         1       1
# ...               ...     ...
# male   NaN          1       1
#        NaN          0       3
#        NaN          0       3
#        NaN          0       3
#        NaN          0       3
#
#                                                          Name  SibSp  Parch  \
# Sex    Age
# female 63.0                 Andrews, Miss. Kornelia Theodosia      1      0
#        63.0                            Turkula, Mrs. (Hedwig)      0      0
#        62.0         Stone, Mrs. George Nelson (Martha Evelyn)      0      0
#        60.0  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)      1      0
#        58.0                          Bonnell, Miss. Elizabeth      0      0
# ...                                                       ...    ...    ...
# ...

# %%
df_ind2
# Out:
#              Survived  Pclass  \
# Sex    Age
# male   22.0         0       3
# female 38.0         1       1
#        26.0         1       3
#        35.0         1       1
# male   35.0         0       3
# ...               ...     ...
#        27.0         0       2
# female 19.0         1       1
#        NaN          0       3
# male   26.0         1       1
#        32.0         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# male   35.0                           Allen, Mr. William Henry      0      0
# ...                                                        ...    ...    ...
# ...

# %%
df_ind2.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_ind2 = df_ind2.reset_index()

# %%
df_ind2.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df_ind2 = df_ind2.set_index(["Survived", "Age"])

# %%
df_ind2
# Out:
#                   Sex  Pclass  \
# Survived Age
# 0        22.0    male       3
# 1        38.0  female       1
#          26.0  female       3
#          35.0  female       1
# 0        35.0    male       3
# ...               ...     ...
#          27.0    male       2
# 1        19.0  female       1
# 0        NaN   female       3
# 1        26.0    male       1
# 0        32.0    male       3
#
#                                                             Name  SibSp  \
# Survived Age
# 0        22.0                            Braund, Mr. Owen Harris      1
# 1        38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
#          26.0                             Heikkinen, Miss. Laina      0
#          35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 0        35.0                           Allen, Mr. William Henry      0
# ...                                                          ...    ...
# ...

# %%
df_ind2.sort_index(ascending=[True, False])
# Out:
#                   Sex  Pclass                                          Name  \
# Survived Age
# 0        74.0    male       3                           Svensson, Mr. Johan
#          71.0    male       1                     Goldschmidt, Mr. George B
#          71.0    male       1                       Artagaveytia, Mr. Ramon
#          70.5    male       3                          Connors, Mr. Patrick
#          70.0    male       2                   Mitchell, Mr. Henry Michael
# ...               ...     ...                                           ...
# 1        NaN   female       3                      Mannion, Miss. Margareth
#          NaN     male       1                   Hawksford, Mr. Walter James
#          NaN     male       3                  McCormack, Mr. Thomas Joseph
#          NaN     male       1                          Marechal, Mr. Pierre
#          NaN   female       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
#
# ...

# %%
df_ind2 = df_ind2.reset_index()

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df.sort_values("Fare", ascending=False)
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 738                 1       1              Lesurer, Mr. Gustave J    male
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 89                  1       1          Fortune, Miss. Mabel Helen  female
# 28                  0       1      Fortune, Mr. Charles Alexander    male
# ...               ...     ...                                 ...     ...
# 634                 0       1       Parr, Mr. William Henry Marsh    male
# 414                 0       2      Cunningham, Mr. Alfred Fleming    male
# 823                 0       1     Reuchlin, Jonkheer. John George    male
# 733                 0       2                Knight, Mr. Robert J    male
# 675                 0       2          Watson, Mr. Ennis Hastings    male
#
# ...

# %%
df.sort_values(["Age", "Fare"], ascending=[False, True])
# Out:
#              Survived  Pclass  \
# PassengerId
# 631                 1       1
# 852                 0       3
# 97                  0       1
# 494                 0       1
# 117                 0       3
# ...               ...     ...
# 307                 1       1
# 335                 1       1
# 32                  1       1
# 528                 0       1
# 558                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 631                       Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 852                                        Svensson, Mr. Johan    male  74.0
# 97                                   Goldschmidt, Mr. George B    male  71.0
# 494                                    Artagaveytia, Mr. Ramon    male  71.0
# 117                                       Connors, Mr. Patrick    male  70.5
# ...                                                        ...     ...   ...
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Name"]
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                         Graham, Miss. Margaret Edith
# 889             Johnston, Miss. Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[["Age", "Name"]]
# Out:
#               Age                                               Name
# PassengerId
# 1            22.0                            Braund, Mr. Owen Harris
# 2            38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3            26.0                             Heikkinen, Miss. Laina
# 4            35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5            35.0                           Allen, Mr. William Henry
# ...           ...                                                ...
# 887          27.0                              Montvila, Rev. Juozas
# 888          19.0                       Graham, Miss. Margaret Edith
# 889           NaN           Johnston, Miss. Catherine Helen "Carrie"
# 890          26.0                              Behr, Mr. Karl Howell
# 891          32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
embarked_value = ['S','C']

filter = df["Embarked"].isin(embarked_value)
df[filter]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 885                 0       3
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df [ df["Embarked"].isin(['S', 'C'])]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 885                 0       3
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.loc[100:105]
# Out:
#              Survived  Pclass                              Name     Sex   Age  \
# PassengerId
# 100                 0       2                 Kantor, Mr. Sinai    male  34.0
# 101                 0       3           Petranec, Miss. Matilda  female  28.0
# 102                 0       3  Petroff, Mr. Pastcho ("Pentcho")    male   NaN
# 103                 0       1         White, Mr. Richard Frasar    male  21.0
# 104                 0       3        Johansson, Mr. Gustaf Joel    male  33.0
# 105                 0       3    Gustafsson, Mr. Anders Vilhelm    male  37.0
#
#              SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 100              1      0   244367  26.0000   NaN        S
# 101              0      0   349245   7.8958   NaN        S
# 102              0      0   349215   7.8958   NaN        S
# 103              0      1    35281  77.2875   D26        S
# 104              0      0     7540   8.6542   NaN        S
# ...

# %%
df.loc[1:50, "Name" : "Ticket"]
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# ...

# %%
df.iloc[0:3, 0:3]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina

# %%
df.iloc[0:3, :]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.iloc[:, :]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.iloc[:, 0:4]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
filtro = df["Age"] >= 40
df[filtro]
# Out:
#              Survived  Pclass  \
# PassengerId
# 7                   0       1
# 12                  1       1
# 16                  1       2
# 31                  0       1
# 34                  0       2
# ...               ...     ...
# 863                 1       1
# 866                 1       2
# 872                 1       1
# 874                 0       3
# 880                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 31                                    Uruchurtu, Don. Manuel E    male  40.0
# 34                                       Wheadon, Mr. Edward H    male  66.0
# ...                                                        ...     ...   ...
# ...

# %%
df[ df["Sex"] == "male"]
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# ...               ...     ...                             ...   ...   ...
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 890                 1       1           Behr, Mr. Karl Howell  male  26.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
filtro_1 = df["Survived"] == 1
filtro_2 = df["Age"] >= 40

df[filtro_1 & filtro_2]
# Out:
#              Survived  Pclass  \
# PassengerId
# 12                  1       1
# 16                  1       2
# 53                  1       1
# 162                 1       2
# 188                 1       1
# ...               ...     ...
# 858                 1       1
# 863                 1       1
# 866                 1       2
# 872                 1       1
# 880                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# 162          Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0
# 188              Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0
# ...                                                        ...     ...   ...
# ...

# %%
df [ (df["Survived"] == 1) & (df["Age"] >= 18) ]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 12                  1       1
# ...               ...     ...
# 875                 1       2
# 880                 1       1
# 881                 1       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.select_dtypes("number")
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500
# ...               ...     ...   ...    ...    ...      ...
# 887                 0       2  27.0      0      0  13.0000
# 888                 1       1  19.0      0      0  30.0000
# 889                 0       3   NaN      1      2  23.4500
# 890                 1       1  26.0      0      0  30.0000
# 891                 0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df.select_dtypes("object")
# Out:
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                        Ticket Cabin Embarked
# PassengerId
# ...

# %%
def verificar_age(valor):
  if valor >= 18:
    return "Acima de 18"
  else:
    return "Abaixo de 18"

# %%
df["Age_categoria"] = df["Age"].apply(lambda x: "Acima de 18" if x > 18 else "Abaixo de 18")

# %%
df["Age_categoria2"] = df["Age"].apply(verificar_age)

# %%
df["Age_categoria2"] = df["Age"].apply(lambda valor: verificar_age(valor))

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df["Age"]
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
177/ df.shape[0]
# Out:
# 0.19865319865319866

# %%
df.isna().sum() #RETORNAR A QUANTIDADE DE VALORES NaN
# Out:
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age               177
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# Age_categoria       0
# Age_categoria2      0
# dtype: int64

# %%
avg_age = df["Age"].mean() #RETORNAR MÉDIA

# %%
avg_age
# Out:
# 29.69911764705882

# %%
coluna_temp = df["Age"].fillna(avg_age)

# %%
coluna_temp.mean()
# Out:
# 29.69911764705882

# %%
df["Age"] = df["Age"].fillna(avg_age)

# %%
df.isna().sum()
# Out:
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# Age_categoria       0
# Age_categoria2      0
# dtype: int64

# %% [markdown]
# ## Análise de dados
#
# Qual a idade máxima e mínima?

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.min()
# Out:
# 0.42

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %% [markdown]
# ## Qual a idade média dos passageiros?

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].median()
# Out:
# 29.69911764705882

# %%
df_temp = pd.DataFrame( #CRIAÇÃO DE UM DATAFRAME
    {"Nome" : ["João", "Pedro", "Maria", "Teresa", "Quitéria"],
     "Salario": [2000, 3000, 4000, 1500, 20000]

    }
)

# %%
df_temp
# Out:
#        Nome  Salario
# 0      João     2000
# 1     Pedro     3000
# 2     Maria     4000
# 3    Teresa     1500
# 4  Quitéria    20000

# %%
df_temp["Salario"].mean()
# Out:
# 6100.0

# %%
df_temp.Salario.median()
# Out:
# 3000.0

# %% [markdown]
# ###PRIORIZAR CALCULO DE MODA EM DADOS QUALITATIVOS (DE CATEGORIA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Name            891 non-null    object
#  3   Sex             891 non-null    object
#  4   Age             891 non-null    float64
#  5   SibSp           891 non-null    int64
#  6   Parch           891 non-null    int64
#  7   Ticket          891 non-null    object
#  8   Fare            891 non-null    float64
#  9   Cabin           204 non-null    object
#  10  Embarked        889 non-null    object
#  11  Age_categoria   891 non-null    object
#  12  Age_categoria2  891 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 129.7+ KB

# %%
df["Embarked"].mode() #COMANDO DE CALCULO DE MODA
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].var() #VARIAÇÃO
# Out:
# 169.0523999372108

# %%
df["Age"].std() #DESVIO PADRÃO PARA MAIS OU PARA MENOS
# Out:
# 13.002015226002882

# %%
df.select_dtypes("number") #MOSTRAR APENAS ITENS NUMÉRICOS PRESENTES EM CADA COLUNA
# Out:
#              Survived  Pclass        Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.000000      1      0   7.2500
# 2                   1       1  38.000000      1      0  71.2833
# 3                   1       3  26.000000      0      0   7.9250
# 4                   1       1  35.000000      1      0  53.1000
# 5                   0       3  35.000000      0      0   8.0500
# ...               ...     ...        ...    ...    ...      ...
# 887                 0       2  27.000000      0      0  13.0000
# 888                 1       1  19.000000      0      0  30.0000
# 889                 0       3  29.699118      1      2  23.4500
# 890                 1       1  26.000000      0      0  30.0000
# 891                 0       3  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df.select_dtypes("number").agg(["mean", "std"]) #APLICANDO MÉDIA E DESVIO PADRÃO EM TODOS OS VALORES NUMÉRICOS DO DATAFRAME
# Out:
#       Survived    Pclass        Age     SibSp     Parch       Fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594  32.204208
# std   0.486592  0.836071  13.002015  1.102743  0.806057  49.693429

# %%
import seaborn as sns

sns.distplot(a=df['Age'])
# Out:
# <ipython-input-81-43855fbf8d02>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df["Survived"].mode()
# Out:
# 0    0
# Name: Survived, dtype: int64

# %%
df[["Age", "Fare"]].agg(["mean", "std"]) #APLICANDO MÉDIA E DESVIO PADRÃO APENAS PARA "Age" e "Fare".
# Out:
#             Age       Fare
# mean  29.699118  32.204208
# std   13.002015  49.693429

# %% [markdown]
# ### Quantil-p
# * Deixa p% dos valores a esquerda.

# %%
lista = [x for x in range(101)]

lista_serie = pd.Series(lista)

# %%
lista_serie.quantile(0.1)
# Out:
# 10.0

# %%
lista_serie.quantile(0.25)
# Out:
# 25.0

# %%
lista_serie.quantile(0.5)
# Out:
# 50.0

# %%
lista_serie.quantile(0.75)
# Out:
# 75.0

# %%
lista_serie.mean()
# Out:
# 50.0

# %%
lista_serie.median()
# Out:
# 50.0

# %%
lista_ser = [x for x in range(1, 110, 2)]

lista_serie2 = pd.Series(lista_ser)

# %%
lista_serie2.median()
# Out:
# 55.0

# %%
df["Age"].quantile(0.9)
# Out:
# 47.0

# %% [markdown]
# ### https://python-graph-gallery.com/ site dos gráficos para usar como referência e como documentação.

# %%
import seaborn as sns

# %%
sns.boxplot( x=df["Survived"], y=df["Age"] )
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# #### Anpalise univariada

# %%
columns = df.select_dtypes("number").columns

# %%
columns_NaN =["Survived", "Pclass"]

df_numbers = df.select_dtypes("number")

# %%
df["Pclass"].unique() #Mostrar a variação de valores dentro de uma coluna
df["Pclass"].nunique() #Mostrar a quantidade de valores distintos dentro de uma coluna
# Out:
# 3

# %%
df_numbers
# Out:
#              Survived  Pclass        Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.000000      1      0   7.2500
# 2                   1       1  38.000000      1      0  71.2833
# 3                   1       3  26.000000      0      0   7.9250
# 4                   1       1  35.000000      1      0  53.1000
# 5                   0       3  35.000000      0      0   8.0500
# ...               ...     ...        ...    ...    ...      ...
# 887                 0       2  27.000000      0      0  13.0000
# 888                 1       1  19.000000      0      0  30.0000
# 889                 0       3  29.699118      1      2  23.4500
# 890                 1       1  26.000000      0      0  30.0000
# 891                 0       3  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df_numbers = df_numbers.drop(columns_NaN, axis = 1) #Removendo dados numéricos categóricos

# %%
df_numbers
# Out:
#                    Age  SibSp  Parch     Fare
# PassengerId
# 1            22.000000      1      0   7.2500
# 2            38.000000      1      0  71.2833
# 3            26.000000      0      0   7.9250
# 4            35.000000      1      0  53.1000
# 5            35.000000      0      0   8.0500
# ...                ...    ...    ...      ...
# 887          27.000000      0      0  13.0000
# 888          19.000000      0      0  30.0000
# 889          29.699118      1      2  23.4500
# 890          26.000000      0      0  30.0000
# 891          32.000000      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
df_numbers.describe(percentiles = [0.1, 0.25, 0.75, 0.9])
# Out:
#               Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean    29.699118    0.523008    0.381594   32.204208
# std     13.002015    1.102743    0.806057   49.693429
# min      0.420000    0.000000    0.000000    0.000000
# 10%     16.000000    0.000000    0.000000    7.550000
# 25%     22.000000    0.000000    0.000000    7.910400
# 50%     29.699118    0.000000    0.000000   14.454200
# 75%     35.000000    1.000000    0.000000   31.000000
# 90%     47.000000    1.000000    2.000000   77.958300
# max     80.000000    8.000000    6.000000  512.329200

# %%
sns.displot(data = df_numbers, x = "Age", bins = 3, stat = "probability")

# %%
sns.displot(data = df_numbers, x = "Age", kind = "kde")

# %%
sns.displot(data = df_numbers, x = "Fare", kind = "kde")

# %%
filters = df_numbers["Fare"] < 0
df_numbers[filters]
# Out:
# Empty DataFrame
# Columns: [Age, SibSp, Parch, Fare]
# Index: []

# %%
df_numbers.query(" Fare < 0")
# Out:
# Empty DataFrame
# Columns: [Age, SibSp, Parch, Fare]
# Index: []

# %%
sns.displot(data = df_numbers, x = "Parch", kind = "kde")

# %%
sns.displot(data = df_numbers, x = "SibSp", kind = "kde")

# %%
df.dtypes
# Out:
# Survived            int64
# Pclass              int64
# Name               object
# Sex                object
# Age               float64
# SibSp               int64
# Parch               int64
# Ticket             object
# Fare              float64
# Cabin              object
# Embarked           object
# Age_categoria      object
# Age_categoria2     object
# dtype: object

# %%
df.select_dtypes("object").columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'Age_categoria',
#        'Age_categoria2'],
#       dtype='object')

# %%
df = df.drop(['Age_categoria', 'Age_categoria2'], axis = 1)

# %%
var_cat_numbers = ["Survived", "Pclass"]

var_cat_numbers =  list(df.select_dtypes("object").columns) + var_cat_numbers

# %%
df[var_cat_numbers] = df[var_cat_numbers].astype('category')

# %%
df.dtypes
# Out:
# Survived    category
# Pclass      category
# Name        category
# Sex         category
# Age          float64
# SibSp          int64
# Parch          int64
# Ticket      category
# Fare         float64
# Cabin       category
# Embarked    category
# dtype: object

# %%
df_cats = df.select_dtypes('category')

# %%
df_cats['Survived'].value_counts()#retornar a quantidade de valores de categoria na na coluna 'Survived'
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df_cats['Survived'].value_counts(normalize = True).mul(100).round(2) #quantidade de aparições de categoria em porcentagem, duas casas decimais com o round(2)
# Out:
# 0    61.62
# 1    38.38
# Name: Survived, dtype: float64

# %%
df_cats['Survived'].value_counts(normalize = True).mul(100).round(2).plot(kind= 'bar')#ANÁLISE UNIVARIADA DE GRÁFICO COM DADOS CATEGORICOS
# Out:
# <Axes: >

# %%
sns.countplot(df_cats, x='Pclass')#analise univariada de contagem no eixo y
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df_cats, x='Pclass', stat = 'probability')#análise probabilística (de porcentagem) no eixo y
# Out:
# <Axes: xlabel='Pclass', ylabel='probability'>

# %%
df_numbers
# Out:
#                    Age  SibSp  Parch     Fare
# PassengerId
# 1            22.000000      1      0   7.2500
# 2            38.000000      1      0  71.2833
# 3            26.000000      0      0   7.9250
# 4            35.000000      1      0  53.1000
# 5            35.000000      0      0   8.0500
# ...                ...    ...    ...      ...
# 887          27.000000      0      0  13.0000
# 888          19.000000      0      0  30.0000
# 889          29.699118      1      2  23.4500
# 890          26.000000      0      0  30.0000
# 891          32.000000      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
sns.scatterplot(df_numbers, x = 'Age', y = 'Fare'); #com ; o texto de cima do grafico sai

# %%
sns.scatterplot(df_numbers, x = 'Age', y = 'Parch');

# %%
df.query('Age == 16')['Parch'].max()
# Out:
# 3

# %%
df[['Age', 'Parch']].corr()
# Out:
#             Age     Parch
# Age    1.000000 -0.179191
# Parch -0.179191  1.000000

# %%
df_numbers.corr()
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.232625 -0.179191  0.091566
# SibSp -0.232625  1.000000  0.414838  0.159651
# Parch -0.179191  0.414838  1.000000  0.216225
# Fare   0.091566  0.159651  0.216225  1.000000

# %%
sns.heatmap(df_numbers.corr()); #sem numeros de correlação

# %%
sns.heatmap(df_numbers.corr(),annot = True); #com os numeros de correlação

# %% [markdown]
# ###### VALOR DE CORRELAÇÃO POSITIVO. A RELAÇÃO É DIRETAMENTE PROPORCIONAL
# ###### VALOR DE CORRELAÇÃO NEGATIVO. A RELAÇÃO É INVERSAMENTE PROPORCIONAL
#
# * Uma relalçao de correlação considerável ocorre acima dos 50%

# %%
sns.heatmap(df_numbers.corr('spearman'), annot = True);

# %%
df_numbers.corr('pearson')#correlação linear
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.232625 -0.179191  0.091566
# SibSp -0.232625  1.000000  0.414838  0.159651
# Parch -0.179191  0.414838  1.000000  0.216225
# Fare   0.091566  0.159651  0.216225  1.000000

# %%
df_numbers.corr('spearman')#correlação não linear
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.147035 -0.217290  0.118847
# SibSp -0.147035  1.000000  0.450014  0.447113
# Parch -0.217290  0.450014  1.000000  0.410074
# Fare   0.118847  0.447113  0.410074  1.000000

# %% [markdown]
# #### correlação não necessariamente é causalidade

# %%
df_cats.groupby('Survived')['Ticket'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Ticket, dtype: int64

# %%
df_cats.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.countplot(df_cats, x = 'Sex', hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df_cats, x = 'Pclass', hue = 'Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df_cats, x = 'Embarked', hue = 'Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
pd.crosstab(df_cats['Pclass'], df_cats["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(df_cats['Pclass'], df_cats["Survived"], normalize = 'index')
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %%
pd.crosstab(df_cats['Pclass'], df_cats["Survived"], normalize = 'index').mul(100).round(2)
# Out:
# Survived      0      1
# Pclass
# 1         37.04  62.96
# 2         52.72  47.28
# 3         75.76  24.24

# %%
pd.crosstab(df_cats['Pclass'], df_cats["Survived"], normalize = 'index', margins = True).mul(100).round(2).plot(kind = 'bar'); #somatorio com o margins

# %%
pd.crosstab(df_cats['Pclass'], df_cats["Survived"], normalize = 'index').mul(100).round(2).plot(kind = 'bar');

# %%
pd.crosstab(df_cats['Embarked'], df_cats["Survived"], normalize = 'index').mul(100).round(2).plot(kind = 'bar');

# %%
sns.boxplot(df, x = 'Survived', y = 'Fare')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.boxplot(df, x = 'Survived', y = 'Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.displot(df, x = 'Age', hue = 'Survived', bins = 5, stat = 'probability')

# %%
sns.displot(df, x = 'Fare', hue = 'Survived', bins = 5, stat = 'probability')

# %%
sns.displot(df, x = 'SibSp', hue = 'Survived', stat = 'probability')

# %%
df['Fare']
# Out:
# PassengerId
# 1       7.2500
# 2      71.2833
# 3       7.9250
# 4      53.1000
# 5       8.0500
#         ...
# 887    13.0000
# 888    30.0000
# 889    23.4500
# 890    30.0000
# 891     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.Fare.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(df, y = 'Fare');

# %%
quartil_2 = df['Fare'].quantile(0.25)
quartil_3 = df['Fare'].quantile(0.75)

inter_quartil = quartil_3 - quartil_2
limite_superior = quartil_3 + (inter_quartil * 1.5)
limite_inferior = quartil_2 - (inter_quartil * 1.5)

# %%
(limite_superior, limite_inferior)
# Out:
# (65.6344, -26.724)

# %%
df.query('Fare > @limite_superior')
# Out:
#             Survived Pclass  \
# PassengerId
# 2                  1      1
# 28                 0      1
# 32                 1      1
# 35                 0      1
# 53                 1      1
# ...              ...    ...
# 847                0      3
# 850                1      1
# 857                1      1
# 864                0      3
# 880                1      1
#
#                                                           Name     Sex  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 28                              Fortune, Mr. Charles Alexander    male
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 35                                     Meyer, Mr. Edgar Joseph    male
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# ...                                                        ...     ...
# 847                                   Sage, Mr. Douglas Bullen    male
# ...

# %%
std = df['Fare'].std()
limite_superior_std = df['Fare'].mean() + (3 * std)
limite_inferior_std = df['Fare'].mean() - (3 * std)

# %%
df[filtro]
# Out:
#             Survived Pclass  \
# PassengerId
# 7                  0      1
# 12                 1      1
# 16                 1      2
# 31                 0      1
# 34                 0      2
# ...              ...    ...
# 863                1      1
# 866                1      2
# 872                1      1
# 874                0      3
# 880                1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 31                                    Uruchurtu, Don. Manuel E    male  40.0
# 34                                       Wheadon, Mr. Edward H    male  66.0
# ...                                                        ...     ...   ...
# ...

# %%
filtro = df['Fare'] > limite_superior_std
df[filtro].shape
# Out:
# (20, 11)

# %%
df_temp2 = df.copy()

# %%
filtro = df['Fare'] > limite_superior_std
df_temp2.loc[filtro, 'Fare'] = limite_superior_std

# %%
limite_superior_std
# Out:
# 181.2844937601173

# %%
df_temp2[filtro]['Fare']
# Out:
# PassengerId
# 28     181.284494
# 89     181.284494
# 119    181.284494
# 259    181.284494
# 300    181.284494
# 312    181.284494
# 342    181.284494
# 378    181.284494
# 381    181.284494
# 439    181.284494
# 528    181.284494
# 558    181.284494
# 680    181.284494
# 690    181.284494
# 701    181.284494
# 717    181.284494
# 731    181.284494
# 738    181.284494
# 743    181.284494
# 780    181.284494
# Name: Fare, dtype: float64

# %%
df_temp2['Cat_Fare'] = pd.qcut(df['Fare'], q = 4, labels = ['1º', '2º', '3º', '4º'])

# %%
df_temp2
# Out:
#             Survived Pclass  \
# PassengerId
# 1                  0      3
# 2                  1      1
# 3                  1      3
# 4                  1      1
# 5                  0      3
# ...              ...    ...
# 887                0      2
# 888                1      1
# 889                0      3
# 890                1      1
# 891                0      3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# ...

# %%
sns.histplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
